# %% [markdown]
# # 예측 애널리틱스: 인공신경망 실습

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1. 모듈 불러오기

# %%
# 실습용 데이터 관련 패키지
import torch
from torchvision.datasets import FashionMNIST

# 데이터 전처리 패키지
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset

# 기계학습 모델 패키지
from sklearn.neural_network import MLPClassifier

# 데이터 시각화 패키지
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
plt.rc('font', family='Malgun Gothic') # 한글 폰트 설정

# 예측 평가 지표 패키지
from sklearn.metrics import accuracy_score, confusion_matrix

# 예측 결과 시각화 custom 함수
def plot_confusion_matrix(cm, classes,title, cmap=plt.cm.Blues):
    
    plt.figure(figsize=(15,15))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title,fontsize=30)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="red" if cm[i, j] > thresh else "black",fontsize=30)

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# 기타
import warnings, itertools, time
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## 2. 데이터 불러오고 로더 만들기

# %%
# Fashion MNIST 데이터를 저장할 directory
download_root = './'

# 데이터 scaling을 위한 요소
fasion_mnist_transform = transforms.Compose([
    transforms.ToTensor(), # 데이터 형태를 Pytorch에 적합한 형태로 바꾸어 줌
    transforms.Normalize((0.0,), (1.0,)) # feature들의 평균과 표준편차를 0과 1로 scaling 해줌
])

#FashionMNIST 훈련 데이터셋 다운로드
dataset = FashionMNIST(download_root, transform=fasion_mnist_transform, train=True, download=True)

# 훈련 데이터셋을 50000개(학습용) / 10000개(검증용)으로 분리
train_dataset, valid_dataset = torch.utils.data.random_split(dataset, [50000, 10000])

# 테스트 데이터셋 다운로드
test_dataset = FashionMNIST(download_root, transform=fasion_mnist_transform, train=False, download=True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3. Sklearn을 이용한 인공신경망 학습

# %% [markdown]
# ### 3-1 모델 구축

# %%
model = MLPClassifier(random_state=0,hidden_layer_sizes=(300,150),activation="relu",solver='adam',
                     batch_size=100,learning_rate='constant',learning_rate_init=0.001,verbose=True,early_stopping=True,
                     validation_fraction=10000/60000, n_iter_no_change=5)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3-2 모델 학습

# %%
start = time.time()  # 모델 학습 시작 시간 저장 28*28=784
model.fit(dataset.data.numpy().reshape(60000,784),dataset.targets.numpy()) # 모델 학습
print("time :", time.time() - start)  # 현재시각 - 시작시간 = 실행 시간
# Out:
# Iteration 1, loss = 3.11262970
# Validation score: 0.804800
# Iteration 2, loss = 0.77369053
# Validation score: 0.813200
# Iteration 3, loss = 0.51863789
# Validation score: 0.833200
# Iteration 4, loss = 0.43735643
# Validation score: 0.846500
# Iteration 5, loss = 0.39513787
# Validation score: 0.857800
# Iteration 6, loss = 0.36550332
# Validation score: 0.854700
# Iteration 7, loss = 0.36762267
# Validation score: 0.853800
# Iteration 8, loss = 0.35562008
# Validation score: 0.842500
# Iteration 9, loss = 0.35231853
# Validation score: 0.862600
# Iteration 10, loss = 0.35499421
# Validation score: 0.846200
# Iteration 11, loss = 0.33910026
# Validation score: 0.871100
# Iteration 12, loss = 0.32919938
# Validation score: 0.869000
# Iteration 13, loss = 0.33823491
# Validation score: 0.860200
# Iteration 14, loss = 0.32743306
# Validation score: 0.868000
# Iteration 15, loss = 0.32557958
# Validation score: 0.872300
# Iteration 16, loss = 0.30679680
# Validation score: 0.864900
# Iteration 17, loss = 0.30306516
# Validation score: 0.871300
# Iteration 18, loss = 0.30767955
# Validation score: 0.874500
# Iteration 19, loss = 0.29154576
# Validation score: 0.868400
# Iteration 20, loss = 0.28767361
# Validation score: 0.882000
# Iteration 21, loss = 0.28547490
# Validation score: 0.871900
# Iteration 22, loss = 0.28231951
# Validation score: 0.871800
# Iteration 23, loss = 0.27915381
# Validation score: 0.878900
# Iteration 24, loss = 0.27359006
# Validation score: 0.879700
# Iteration 25, loss = 0.26961524
# Validation score: 0.884600
# Iteration 26, loss = 0.27255506
# Validation score: 0.881800
# Iteration 27, loss = 0.25922108
# Validation score: 0.878900
# Iteration 28, loss = 0.26155846
# Validation score: 0.879300
# Iteration 29, loss = 0.25568102
# Validation score: 0.881300
# Iteration 30, loss = 0.25070465
# Validation score: 0.889700
# Iteration 31, loss = 0.25409789
# Validation score: 0.886800
# Iteration 32, loss = 0.24116144
# Validation score: 0.886500
# Iteration 33, loss = 0.25650012
# Validation score: 0.888000
# Iteration 34, loss = 0.23508796
# Validation score: 0.887700
# Iteration 35, loss = 0.23805114
# Validation score: 0.878600
# Iteration 36, loss = 0.23360377
# Validation score: 0.875900
# Validation score did not improve more than tol=0.000100 for 5 consecutive epochs. Stopping.
# time : 146.00235438346863

# %% [markdown]
# ### 3-3 학습 현황 확인 및 예측 결과 출력

# %%
# 모델의 training loss
train_loss = model.loss_curve_

# 그래프 배경화면 만들기
f, axs = plt.subplots(2,1,figsize=(20,10))

# 학습로스 변동 관찰하기
axs[0].plot(train_loss,label='학습 로스')
axs[0].legend()

# 검증용 데이터에 대한 Accuracy 변동 관찰하기
axs[1].plot(model.validation_scores_,label='검증 데이터에 대한 Accuracy')
axs[1].scatter(np.argmax(model.validation_scores_),np.max(model.validation_scores_),s=100,facecolors='none',edgecolors='r',
              label='최적의 학습 체크포인트(=학습 중단점)')
axs[1].legend()
plt.show()

# %%
# 예측 Accuracy 확인하기
train_accuracy = accuracy_score(y_pred=model.predict(dataset.data.numpy().reshape(60000,-1)),y_true=dataset.targets.numpy())
test_accuracy = accuracy_score(y_pred=model.predict(test_dataset.data.numpy().reshape(10000,-1)),y_true=test_dataset.targets.numpy())
print(f"훈련 데이터셋 정확도: {train_accuracy:.3f}",f"테스트용 데이터셋 정확도: {test_accuracy:.3f}",sep='  |  ')
# Out:
# 훈련 데이터셋 정확도: 0.912  |  테스트용 데이터셋 정확도: 0.876

# %%
confusion_matrix_ = confusion_matrix(y_pred=model.predict(test_dataset.data.numpy().reshape(10000,-1)),y_true=test_dataset.targets.numpy())
plot_confusion_matrix(cm = confusion_matrix_, classes=dataset.classes,title='Fashion MNIST 테스팅 데이터 혼동행렬')

# %%
for_visualization_test_x = test_dataset.data.numpy()[:100]
for_visualization_test_y = test_dataset.targets.numpy()[:100]

f ,axs = plt.subplots(10,10,figsize=(20,20))
plt.subplots_adjust(hspace=0.8)
for i in range(10):
    for j in range(10):
        
        x_data = for_visualization_test_x[10*i+j]
        y_data = for_visualization_test_y[10*i+j]
        real_class = dataset.classes[y_data]
        predicted_class = dataset.classes[np.argmax(model.predict_proba(x_data.reshape(1,-1)))]
        predicted_prob = np.max(model.predict_proba(x_data.reshape(1,-1))).round(2)
        
        # x, y 축의 지점 표시를 안함
        axs[i,j].set_xticks([])
        axs[i,j].set_yticks([])

        # subplot의 제목을 i번째 결과에 해당하는 숫자로 설정
        axs[i,j].set_title(f"실제 class:{real_class}\n예측 class:{predicted_class}\nProbability:{predicted_prob}")

        # 입력으로 사용한 i번째 테스트 이미지를 28x28로 재배열하고
        # 이 2차원 배열을 그레이스케일 이미지로 출력
        axs[i,j].imshow(x_data.reshape((28, 28)),cmap=plt.cm.gray_r)
 
plt.show()

# %% [markdown]
# # EOD
